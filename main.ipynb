# %%
import numpy as np
import gymnasium as gym
import random

# Hyperparameter
population_size = 100
num_generations = 200
mutation_rate = 0.1
crossover_rate = 0.5
elitism = True
elite_size = 5

# Environment
env = gym.make('MountainCar-v0')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n

# Initialize population
def initialize_population():
    return [np.random.randn(state_size, action_size) for _ in range(population_size)]

# Fitness function
def fitness(chromosome):
    state, _ = env.reset()
    total_reward = 0
    for _ in range(200):
        action = np.argmax(np.dot(state, chromosome))
        state, reward, done, _, _ = env.step(action)
        total_reward += reward
        if done:
            break
    return total_reward  # Note: total_reward is negative

# Selection
def selection(population, fitnesses):
    # Ensure all fitness values are positive by adding a constant if necessary
    min_fitness = min(fitnesses)
    offset = abs(min_fitness) + 1 if min_fitness < 0 else 0
    adjusted_fitnesses = [f + offset for f in fitnesses]

    selected = random.choices(population, weights=adjusted_fitnesses, k=len(population) - elite_size)
    return selected

# Crossover
def crossover(parent1, parent2):
    if random.random() < crossover_rate:
        point = random.randint(1, state_size - 1)
        child1 = np.vstack((parent1[:point], parent2[point:]))
        child2 = np.vstack((parent2[:point], parent1[point:]))
        return child1, child2
    else:
        return parent1, parent2

# Mutation
def mutate(chromosome):
    if random.random() < mutation_rate:
        index = random.randint(0, state_size - 1)
        chromosome[index] = np.random.randn(action_size)
    return chromosome

# Main algorithm
population = initialize_population()
best_fitness = -float('inf')
best_chromosome = None

for generation in range(num_generations):
    fitnesses = [fitness(chromosome) for chromosome in population]
    max_fitness = max(fitnesses)
    if max_fitness > best_fitness:
        best_fitness = max_fitness
        best_chromosome = population[np.argmax(fitnesses)].copy()  # Ensure we copy the best chromosome
    print(f'Generation {generation} | Best fitness: {max_fitness}')
    
    # Apply elitism
    elite_indices = np.argsort(fitnesses)[-elite_size:]
    elites = [population[i] for i in elite_indices]
    
    selected_population = selection(population, fitnesses)
    next_population = []
    for i in range(0, len(selected_population) - 1, 2):
        parent1 = selected_population[i]
        parent2 = selected_population[i + 1]
        child1, child2 = crossover(parent1, parent2)
        next_population.extend([mutate(child1), mutate(child2)])
    
    # Add elites to the next population
    next_population.extend(elites)
    
    # Handle the case when the selected population size is odd
    if len(selected_population) % 2 != 0:
        next_population.append(selected_population[-1])

    population = next_population

# Save the best chromosome
np.save('best_chromosome.npy', best_chromosome)
print('Best solution found:', best_chromosome)

# Example of using the saved model
env = gym.make('MountainCar-v0', render_mode='human')
def load_model():
    return np.load('best_chromosome.npy')

def run_model(chromosome):
    state, _ = env.reset()
    total_reward = 0
    for _ in range(200):
        env.render()
        action = np.argmax(np.dot(state, chromosome))
        state, reward, done, _, _ = env.step(action)
        total_reward += reward
        if done:
            break
    env.close()
    return total_reward  # Total reward (negative value) reflects the number of steps

# Load the model and run it
best_chromosome = load_model()
total_reward = run_model(best_chromosome)
print('Total reward using the best model:', total_reward)
# Out:
# Generation 0 | Best fitness: -200.0
# Generation 1 | Best fitness: -200.0
# Generation 2 | Best fitness: -200.0
# Generation 3 | Best fitness: -121.0
# Generation 4 | Best fitness: -121.0
# Generation 5 | Best fitness: -121.0
# Generation 6 | Best fitness: -122.0
# Generation 7 | Best fitness: -200.0
# Generation 8 | Best fitness: -131.0
# Generation 9 | Best fitness: -123.0
# Generation 10 | Best fitness: -118.0
# Generation 11 | Best fitness: -117.0
# Generation 12 | Best fitness: -116.0
# Generation 13 | Best fitness: -117.0
# Generation 14 | Best fitness: -117.0
# Generation 15 | Best fitness: -117.0
# Generation 16 | Best fitness: -116.0
# Generation 17 | Best fitness: -117.0
# Generation 18 | Best fitness: -116.0
# Generation 19 | Best fitness: -117.0
# Generation 20 | Best fitness: -116.0
# Generation 21 | Best fitness: -116.0
# Generation 22 | Best fitness: -117.0
# Generation 23 | Best fitness: -116.0
# Generation 24 | Best fitness: -116.0
# Generation 25 | Best fitness: -116.0
# Generation 26 | Best fitness: -116.0
# Generation 27 | Best fitness: -116.0
# Generation 28 | Best fitness: -116.0
# Generation 29 | Best fitness: -116.0
# Generation 30 | Best fitness: -116.0
# Generation 31 | Best fitness: -115.0
# Generation 32 | Best fitness: -116.0
# Generation 33 | Best fitness: -115.0
# Generation 34 | Best fitness: -116.0
# Generation 35 | Best fitness: -115.0
# Generation 36 | Best fitness: -115.0
# Generation 37 | Best fitness: -115.0
# Generation 38 | Best fitness: -115.0
# Generation 39 | Best fitness: -115.0
# Generation 40 | Best fitness: -116.0
# Generation 41 | Best fitness: -116.0
# Generation 42 | Best fitness: -116.0
# Generation 43 | Best fitness: -115.0
# Generation 44 | Best fitness: -115.0
# Generation 45 | Best fitness: -115.0
# Generation 46 | Best fitness: -115.0
# Generation 47 | Best fitness: -116.0
# Generation 48 | Best fitness: -116.0
# Generation 49 | Best fitness: -116.0
# Generation 50 | Best fitness: -115.0
# Generation 51 | Best fitness: -115.0
# Generation 52 | Best fitness: -115.0
# Generation 53 | Best fitness: -115.0
# Generation 54 | Best fitness: -115.0
# Generation 55 | Best fitness: -115.0
# Generation 56 | Best fitness: -115.0
# Generation 57 | Best fitness: -115.0
# Generation 58 | Best fitness: -115.0
# Generation 59 | Best fitness: -115.0
# Generation 60 | Best fitness: -115.0
# Generation 61 | Best fitness: -115.0
# Generation 62 | Best fitness: -115.0
# Generation 63 | Best fitness: -115.0
# Generation 64 | Best fitness: -115.0
# Generation 65 | Best fitness: -115.0
# Generation 66 | Best fitness: -115.0
# Generation 67 | Best fitness: -115.0
# Generation 68 | Best fitness: -115.0
# Generation 69 | Best fitness: -114.0
# Generation 70 | Best fitness: -115.0
# Generation 71 | Best fitness: -115.0
# Generation 72 | Best fitness: -115.0
# Generation 73 | Best fitness: -115.0
# Generation 74 | Best fitness: -114.0
# Generation 75 | Best fitness: -115.0
# Generation 76 | Best fitness: -115.0
# Generation 77 | Best fitness: -115.0
# Generation 78 | Best fitness: -115.0
# Generation 79 | Best fitness: -115.0
# Generation 80 | Best fitness: -115.0
# Generation 81 | Best fitness: -115.0
# Generation 82 | Best fitness: -115.0
# Generation 83 | Best fitness: -115.0
# Generation 84 | Best fitness: -115.0
# Generation 85 | Best fitness: -115.0
# Generation 86 | Best fitness: -115.0
# Generation 87 | Best fitness: -115.0
# Generation 88 | Best fitness: -115.0
# Generation 89 | Best fitness: -115.0
# Generation 90 | Best fitness: -115.0
# Generation 91 | Best fitness: -115.0
# Generation 92 | Best fitness: -115.0
# Generation 93 | Best fitness: -115.0
# Generation 94 | Best fitness: -115.0
# Generation 95 | Best fitness: -115.0
# Generation 96 | Best fitness: -115.0
# Generation 97 | Best fitness: -115.0
# Generation 98 | Best fitness: -115.0
# Generation 99 | Best fitness: -115.0
# Generation 100 | Best fitness: -115.0
# Generation 101 | Best fitness: -115.0
# Generation 102 | Best fitness: -115.0
# Generation 103 | Best fitness: -115.0
# Generation 104 | Best fitness: -115.0
# Generation 105 | Best fitness: -115.0
# Generation 106 | Best fitness: -115.0
# Generation 107 | Best fitness: -115.0
# Generation 108 | Best fitness: -114.0
# Generation 109 | Best fitness: -115.0
# Generation 110 | Best fitness: -115.0
# Generation 111 | Best fitness: -115.0
# Generation 112 | Best fitness: -115.0
# Generation 113 | Best fitness: -115.0
# Generation 114 | Best fitness: -115.0
# Generation 115 | Best fitness: -115.0
# Generation 116 | Best fitness: -115.0
# Generation 117 | Best fitness: -115.0
# Generation 118 | Best fitness: -115.0
# Generation 119 | Best fitness: -115.0
# Generation 120 | Best fitness: -115.0
# Generation 121 | Best fitness: -115.0
# Generation 122 | Best fitness: -115.0
# Generation 123 | Best fitness: -115.0
# Generation 124 | Best fitness: -115.0
# Generation 125 | Best fitness: -115.0
# Generation 126 | Best fitness: -115.0
# Generation 127 | Best fitness: -115.0
# Generation 128 | Best fitness: -115.0
# Generation 129 | Best fitness: -115.0
# Generation 130 | Best fitness: -115.0
# Generation 131 | Best fitness: -115.0
# Generation 132 | Best fitness: -114.0
# Generation 133 | Best fitness: -114.0
# Generation 134 | Best fitness: -114.0
# Generation 135 | Best fitness: -115.0
# Generation 136 | Best fitness: -115.0
# Generation 137 | Best fitness: -115.0
# Generation 138 | Best fitness: -115.0
# Generation 139 | Best fitness: -115.0
# Generation 140 | Best fitness: -115.0
# Generation 141 | Best fitness: -115.0
# Generation 142 | Best fitness: -115.0
# Generation 143 | Best fitness: -115.0
# Generation 144 | Best fitness: -114.0
# Generation 145 | Best fitness: -115.0
# Generation 146 | Best fitness: -114.0
# Generation 147 | Best fitness: -115.0
# Generation 148 | Best fitness: -114.0
# Generation 149 | Best fitness: -115.0
# Generation 150 | Best fitness: -115.0
# Generation 151 | Best fitness: -115.0
# Generation 152 | Best fitness: -115.0
# Generation 153 | Best fitness: -114.0
# Generation 154 | Best fitness: -115.0
# Generation 155 | Best fitness: -115.0
# Generation 156 | Best fitness: -114.0
# Generation 157 | Best fitness: -114.0
# Generation 158 | Best fitness: -115.0
# Generation 159 | Best fitness: -115.0
# Generation 160 | Best fitness: -115.0
# Generation 161 | Best fitness: -115.0
# Generation 162 | Best fitness: -115.0
# Generation 163 | Best fitness: -115.0
# Generation 164 | Best fitness: -115.0
# Generation 165 | Best fitness: -115.0
# Generation 166 | Best fitness: -115.0
# Generation 167 | Best fitness: -115.0
# Generation 168 | Best fitness: -115.0
# Generation 169 | Best fitness: -115.0
# Generation 170 | Best fitness: -115.0
# Generation 171 | Best fitness: -114.0
# Generation 172 | Best fitness: -114.0
# Generation 173 | Best fitness: -114.0
# Generation 174 | Best fitness: -114.0
# Generation 175 | Best fitness: -115.0
# Generation 176 | Best fitness: -115.0
# Generation 177 | Best fitness: -114.0
# Generation 178 | Best fitness: -115.0
# Generation 179 | Best fitness: -115.0
# Generation 180 | Best fitness: -115.0
# Generation 181 | Best fitness: -114.0
# Generation 182 | Best fitness: -114.0
# Generation 183 | Best fitness: -114.0
# Generation 184 | Best fitness: -115.0
# Generation 185 | Best fitness: -114.0
# Generation 186 | Best fitness: -114.0
# Generation 187 | Best fitness: -114.0
# Generation 188 | Best fitness: -115.0
# Generation 189 | Best fitness: -114.0
# Generation 190 | Best fitness: -114.0
# Generation 191 | Best fitness: -114.0
# Generation 192 | Best fitness: -114.0
# Generation 193 | Best fitness: -114.0
# Generation 194 | Best fitness: -114.0
# Generation 195 | Best fitness: -114.0
# Generation 196 | Best fitness: -114.0
# Generation 197 | Best fitness: -115.0
# Generation 198 | Best fitness: -114.0
# Generation 199 | Best fitness: -114.0
# Best solution found: [[ 0.57256861  1.53472414  0.54535279]
#  [-0.32246355 -0.56911525  3.05464854]]
# 2024-07-30 21:45:38.655 Python[81429:15475608] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# Total reward using the best model: -132.0
