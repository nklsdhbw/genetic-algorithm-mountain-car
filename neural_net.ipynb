# %%
import numpy as np
import gymnasium as gym
import random

# Hyperparameter
population_size = 100
num_generations = 200
mutation_rate = 0.1
crossover_rate = 0.5
elitism = True
elite_size = 5

# Environment
env = gym.make('MountainCar-v0')
state_size = env.observation_space.shape[0]
hidden_size = 10  # Größe der versteckten Schicht
action_size = env.action_space.n

# Initialize population
def initialize_population():
    return [{
        'w1': np.random.randn(state_size, hidden_size),
        'b1': np.random.randn(hidden_size),
        'w2': np.random.randn(hidden_size, action_size),
        'b2': np.random.randn(action_size)
    } for _ in range(population_size)]

# Forward pass of the neural network
def forward_pass(state, chromosome):
    z1 = np.dot(state, chromosome['w1']) + chromosome['b1']
    a1 = np.tanh(z1)
    z2 = np.dot(a1, chromosome['w2']) + chromosome['b2']
    return z2

# Fitness function
def fitness(chromosome):
    state, _ = env.reset()
    total_reward = 0
    for _ in range(200):
        action_values = forward_pass(state, chromosome)
        action = np.argmax(action_values)
        state, reward, done, _, _ = env.step(action)
        total_reward += reward
        if done:
            break
    return total_reward  # Note: total_reward is negative

# Selection
def selection(population, fitnesses):
    min_fitness = min(fitnesses)
    offset = abs(min_fitness) + 1 if min_fitness < 0 else 0
    adjusted_fitnesses = [f + offset for f in fitnesses]
    selected = random.choices(population, weights=adjusted_fitnesses, k=len(population) - elite_size)
    return selected

# Crossover
def crossover(parent1, parent2):
    child1 = {}
    child2 = {}
    for key in parent1.keys():
        if random.random() < crossover_rate:
            point = random.randint(1, parent1[key].shape[0] - 1)
            if parent1[key].ndim == 1:
                child1[key] = np.concatenate((parent1[key][:point], parent2[key][point:]))
                child2[key] = np.concatenate((parent2[key][:point], parent1[key][point:]))
            else:
                child1[key] = np.vstack((parent1[key][:point, :], parent2[key][point:, :]))
                child2[key] = np.vstack((parent2[key][:point, :], parent1[key][point:, :]))
        else:
            child1[key] = parent1[key].copy()
            child2[key] = parent2[key].copy()
    return child1, child2

# Mutation
def mutate(chromosome):
    for key in chromosome.keys():
        if random.random() < mutation_rate:
            index = random.randint(0, chromosome[key].shape[0] - 1)
            if chromosome[key].ndim == 1:
                chromosome[key][index] = np.random.randn()
            else:
                chromosome[key][index, :] = np.random.randn(chromosome[key].shape[1])
    return chromosome

# Main algorithm
population = initialize_population()
best_fitness = -float('inf')
best_chromosome = None

for generation in range(num_generations):
    fitnesses = [fitness(chromosome) for chromosome in population]
    max_fitness = max(fitnesses)
    if max_fitness > best_fitness:
        best_fitness = max_fitness
        best_chromosome = population[np.argmax(fitnesses)].copy()  # Ensure we copy the best chromosome
    print(f'Generation {generation} | Best fitness: {max_fitness}')
    
    # Apply elitism
    elite_indices = np.argsort(fitnesses)[-elite_size:]
    elites = [population[i] for i in elite_indices]
    
    selected_population = selection(population, fitnesses)
    next_population = []
    for i in range(0, len(selected_population) - 1, 2):
        parent1 = selected_population[i]
        parent2 = selected_population[i + 1]
        child1, child2 = crossover(parent1, parent2)
        next_population.extend([mutate(child1), mutate(child2)])
    
    # Add elites to the next population
    next_population.extend(elites)
    
    # Handle the case when the selected population size is odd
    if len(selected_population) % 2 != 0:
        next_population.append(selected_population[-1])

    population = next_population

# Save the best chromosome
np.save('best_chromosome_nn.npy', best_chromosome)
print('Best solution found:', best_chromosome)

# Example of using the saved model
env = gym.make('MountainCar-v0', render_mode='human')
def load_model():
    return np.load('best_chromosome_nn.npy', allow_pickle=True).item()

def run_model(chromosome):
    state, _ = env.reset()
    total_reward = 0
    for _ in range(200):
        env.render()
        action_values = forward_pass(state, chromosome)
        action = np.argmax(action_values)
        state, reward, done, _, _ = env.step(action)
        total_reward += reward
        if done:
            break
    env.close()
    return total_reward  # Total reward (negative value) reflects the number of steps

# Load the model and run it
best_chromosome = load_model()
total_reward = run_model(best_chromosome)
print('Total reward using the best model:', total_reward)
# Out:
# Generation 0 | Best fitness: -200.0
# Generation 1 | Best fitness: -200.0
# Generation 2 | Best fitness: -200.0
# Generation 3 | Best fitness: -200.0
# Generation 4 | Best fitness: -200.0
# Generation 5 | Best fitness: -200.0
# Generation 6 | Best fitness: -200.0
# Generation 7 | Best fitness: -200.0
# Generation 8 | Best fitness: -200.0
# Generation 9 | Best fitness: -200.0
# Generation 10 | Best fitness: -200.0
# Generation 11 | Best fitness: -200.0
# Generation 12 | Best fitness: -200.0
# Generation 13 | Best fitness: -200.0
# Generation 14 | Best fitness: -200.0
# Generation 15 | Best fitness: -200.0
# Generation 16 | Best fitness: -200.0
# Generation 17 | Best fitness: -200.0
# Generation 18 | Best fitness: -200.0
# Generation 19 | Best fitness: -200.0
# Generation 20 | Best fitness: -200.0
# Generation 21 | Best fitness: -200.0
# Generation 22 | Best fitness: -200.0
# Generation 23 | Best fitness: -200.0
# Generation 24 | Best fitness: -200.0
# Generation 25 | Best fitness: -200.0
# Generation 26 | Best fitness: -200.0
# Generation 27 | Best fitness: -200.0
# Generation 28 | Best fitness: -200.0
# Generation 29 | Best fitness: -200.0
# Generation 30 | Best fitness: -200.0
# Generation 31 | Best fitness: -200.0
# Generation 32 | Best fitness: -200.0
# Generation 33 | Best fitness: -200.0
# Generation 34 | Best fitness: -200.0
# Generation 35 | Best fitness: -200.0
# Generation 36 | Best fitness: -200.0
# Generation 37 | Best fitness: -200.0
# Generation 38 | Best fitness: -200.0
# Generation 39 | Best fitness: -200.0
# Generation 40 | Best fitness: -200.0
# Generation 41 | Best fitness: -200.0
# Generation 42 | Best fitness: -200.0
# Generation 43 | Best fitness: -200.0
# Generation 44 | Best fitness: -200.0
# Generation 45 | Best fitness: -200.0
# Generation 46 | Best fitness: -200.0
# Generation 47 | Best fitness: -200.0
# Generation 48 | Best fitness: -200.0
# Generation 49 | Best fitness: -200.0
# Generation 50 | Best fitness: -200.0
# Generation 51 | Best fitness: -200.0
# Generation 52 | Best fitness: -200.0
# Generation 53 | Best fitness: -200.0
# Generation 54 | Best fitness: -182.0
# Generation 55 | Best fitness: -167.0
# Generation 56 | Best fitness: -167.0
# Generation 57 | Best fitness: -167.0
# Generation 58 | Best fitness: -138.0
# Generation 59 | Best fitness: -139.0
# Generation 60 | Best fitness: -139.0
# Generation 61 | Best fitness: -109.0
# Generation 62 | Best fitness: -109.0
# Generation 63 | Best fitness: -109.0
# Generation 64 | Best fitness: -109.0
# Generation 65 | Best fitness: -109.0
# Generation 66 | Best fitness: -109.0
# Generation 67 | Best fitness: -107.0
# Generation 68 | Best fitness: -107.0
# Generation 69 | Best fitness: -109.0
# Generation 70 | Best fitness: -109.0
# Generation 71 | Best fitness: -107.0
# Generation 72 | Best fitness: -109.0
# Generation 73 | Best fitness: -107.0
# Generation 74 | Best fitness: -107.0
# Generation 75 | Best fitness: -107.0
# Generation 76 | Best fitness: -107.0
# Generation 77 | Best fitness: -107.0
# Generation 78 | Best fitness: -107.0
# Generation 79 | Best fitness: -107.0
# Generation 80 | Best fitness: -107.0
# Generation 81 | Best fitness: -107.0
# Generation 82 | Best fitness: -107.0
# Generation 83 | Best fitness: -107.0
# Generation 84 | Best fitness: -107.0
# Generation 85 | Best fitness: -107.0
# Generation 86 | Best fitness: -107.0
# Generation 87 | Best fitness: -107.0
# Generation 88 | Best fitness: -106.0
# Generation 89 | Best fitness: -106.0
# Generation 90 | Best fitness: -106.0
# Generation 91 | Best fitness: -106.0
# Generation 92 | Best fitness: -106.0
# Generation 93 | Best fitness: -107.0
# Generation 94 | Best fitness: -107.0
# Generation 95 | Best fitness: -107.0
# Generation 96 | Best fitness: -106.0
# Generation 97 | Best fitness: -107.0
# Generation 98 | Best fitness: -106.0
# Generation 99 | Best fitness: -106.0
# Generation 100 | Best fitness: -107.0
# Generation 101 | Best fitness: -106.0
# Generation 102 | Best fitness: -106.0
# Generation 103 | Best fitness: -106.0
# Generation 104 | Best fitness: -106.0
# Generation 105 | Best fitness: -106.0
# Generation 106 | Best fitness: -106.0
# Generation 107 | Best fitness: -106.0
# Generation 108 | Best fitness: -106.0
# Generation 109 | Best fitness: -85.0
# Generation 110 | Best fitness: -87.0
# Generation 111 | Best fitness: -87.0
# Generation 112 | Best fitness: -85.0
# Generation 113 | Best fitness: -97.0
# Generation 114 | Best fitness: -89.0
# Generation 115 | Best fitness: -93.0
# Generation 116 | Best fitness: -83.0
# Generation 117 | Best fitness: -85.0
# Generation 118 | Best fitness: -89.0
# Generation 119 | Best fitness: -84.0
# Generation 120 | Best fitness: -83.0
# Generation 121 | Best fitness: -84.0
# Generation 122 | Best fitness: -83.0
# Generation 123 | Best fitness: -83.0
# Generation 124 | Best fitness: -87.0
# Generation 125 | Best fitness: -84.0
# Generation 126 | Best fitness: -87.0
# Generation 127 | Best fitness: -83.0
# Generation 128 | Best fitness: -84.0
# Generation 129 | Best fitness: -84.0
# Generation 130 | Best fitness: -83.0
# Generation 131 | Best fitness: -84.0
# Generation 132 | Best fitness: -83.0
# Generation 133 | Best fitness: -83.0
# Generation 134 | Best fitness: -84.0
# Generation 135 | Best fitness: -84.0
# Generation 136 | Best fitness: -84.0
# Generation 137 | Best fitness: -83.0
# Generation 138 | Best fitness: -84.0
# Generation 139 | Best fitness: -83.0
# Generation 140 | Best fitness: -83.0
# Generation 141 | Best fitness: -83.0
# Generation 142 | Best fitness: -84.0
# Generation 143 | Best fitness: -84.0
# Generation 144 | Best fitness: -84.0
# Generation 145 | Best fitness: -83.0
# Generation 146 | Best fitness: -83.0
# Generation 147 | Best fitness: -85.0
# Generation 148 | Best fitness: -85.0
# Generation 149 | Best fitness: -84.0
# Generation 150 | Best fitness: -91.0
# Generation 151 | Best fitness: -106.0
# Generation 152 | Best fitness: -106.0
# Generation 153 | Best fitness: -106.0
# Generation 154 | Best fitness: -106.0
# Generation 155 | Best fitness: -106.0
# Generation 156 | Best fitness: -106.0
# Generation 157 | Best fitness: -106.0
# Generation 158 | Best fitness: -106.0
# Generation 159 | Best fitness: -107.0
# Generation 160 | Best fitness: -107.0
# Generation 161 | Best fitness: -106.0
# Generation 162 | Best fitness: -106.0
# Generation 163 | Best fitness: -106.0
# Generation 164 | Best fitness: -106.0
# Generation 165 | Best fitness: -106.0
# Generation 166 | Best fitness: -107.0
# Generation 167 | Best fitness: -106.0
# Generation 168 | Best fitness: -97.0
# Generation 169 | Best fitness: -93.0
# Generation 170 | Best fitness: -106.0
# Generation 171 | Best fitness: -106.0
# Generation 172 | Best fitness: -106.0
# Generation 173 | Best fitness: -106.0
# Generation 174 | Best fitness: -106.0
# Generation 175 | Best fitness: -106.0
# Generation 176 | Best fitness: -106.0
# Generation 177 | Best fitness: -106.0
# Generation 178 | Best fitness: -106.0
# Generation 179 | Best fitness: -106.0
# Generation 180 | Best fitness: -106.0
# Generation 181 | Best fitness: -106.0
# Generation 182 | Best fitness: -106.0
# Generation 183 | Best fitness: -106.0
# Generation 184 | Best fitness: -107.0
# Generation 185 | Best fitness: -106.0
# Generation 186 | Best fitness: -106.0
# Generation 187 | Best fitness: -107.0
# Generation 188 | Best fitness: -106.0
# Generation 189 | Best fitness: -106.0
# Generation 190 | Best fitness: -107.0
# Generation 191 | Best fitness: -106.0
# Generation 192 | Best fitness: -106.0
# Generation 193 | Best fitness: -106.0
# Generation 194 | Best fitness: -106.0
# Generation 195 | Best fitness: -106.0
# Generation 196 | Best fitness: -106.0
# Generation 197 | Best fitness: -107.0
# Generation 198 | Best fitness: -106.0
# Generation 199 | Best fitness: -106.0
# Best solution found: {'w1': array([[-0.5565944 ,  0.54354875, -0.01910505,  1.62862296, -1.60501224,
#         -0.51273053, -0.0587842 ,  1.91627525,  0.49667934, -0.04018048],
#        [ 0.26060119,  2.07457335,  0.03412026,  0.40467932,  1.77848109,
#          0.97279699, -0.28855233, -1.24268952, -1.20092727,  1.50365372]]), 'b1': array([ 0.04111341, -0.91781653, -0.49700467, -1.17877459,  0.49844103,
#         1.46802993,  1.52492015, -0.91196809, -1.29169824, -0.41412763]), 'w2': array([[ 1.49401563,  0.64077484,  2.06601268],
#        [-1.26344897,  1.59344059,  0.95112447],
#        [ 0.30054558,  1.06756856,  0.04869109],
#        [-1.21224653,  1.17219423, -0.97517303],
#        [ 0.4820085 , -0.35990817, -0.01962509],
#        [-0.77993228, -1.2911408 , -0.29798164],
#        [-1.62436976, -1.95765207,  0.56716465],
#        [ 0.887522  , -0.82484601,  0.3003936 ],
#        [ 0.7453724 ,  0.99885051, -1.06060084],
#        [-0.04919227,  0.30299941,  1.23290206]]), 'b2': array([ 0.82364694,  0.46141486, -1.16033928])}
# 2024-07-30 22:19:51.919 Python[4651:15551559] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# Total reward using the best model: -103.0
